# %% [markdown]
# # Пройденые темы, а также вопросы и задачи к ним

# %% [markdown]
# ## Формализации задач на теорию вероятности
#
# На множестве из n уникальных элементов:
# - Найдите количество уникальных перестановок.
# - Найдите количество способов выбрать подмножество мощности k. Покажите, как это число подмножеств связано с битовыми масками длины n.
# - Найдите общее количество уникальных подмножеств.
# - Найдите количество уникальных способов упорядоченно разместить k элементов.

# %% [markdown]
# ## Выборочный метод
#
# - Дайте определение теоретической выборки и покажите её отличие от выборки реализаций.
# - Дайте определение функции распределения.
# - Дайте определение функции массы вероятности для дискретных распределений.
# - Дайте определение вариационного ряда.
# - Дайте определение эмпирической функции распределения.
#
#
# ## Условная вероятность и метод Байеса
#
# - Дайте определение условной вероятности события.
# - Дайте определение теоремы Байеса.
# - Покажите формульно, как, зная условные вероятности события при наступивших гипотезах и частные вероятности гипотез, получить вероятность того, что событие произошло из-за i-й гипотезы.
# - Дайте определение совместного распределения случайных величин (распределение вектора случайных величин).
# - Дайте определение условного распределения случайной величины из случайного вектора.
#
# ## Ковариация
# - Напишите две формулы ковариации двух случайных величин.
# - Найдите, чему равна ковариация двух независимых СВ. Гарантирует ли нулевая ковариация независимость?
# - Продемонстрируйте формульно и докажите по определению свойства ковариации: линейность по случайным величинам и умножению на константу, инвариантность к сдвигам.
# - Найдите в общем виде дисперсию линейной комбинации четырех (возможно, зависимых) случайных величин $D(4X -7Y + 3Z + W)$. Что происходит с ней, если Y, Z и W независимы в совокупности?

# %% [markdown]
# ## Сходимости случайных величин
#
# ### Разные сходимости случайных величин
#
# - Дайте определение сходимости "почти всюду".
# - Дайте определение сходимости по вероятности.
# - Дайте определение сходимости по распределению.
# - Опишите соотношения между видами сходимостей (какая из какой следует).
#
# ### Неравенства Маркова и Чебышёва
#
# - Сформулируйте неравенство Маркова.
# - Сформулируйте неравенство Чебышёва.
# - Объясните, как использовать неравенство Чебышёва, чтобы находить минимальное n для заданной точности и достижимую точность по заданному n.
#
# ### Закон Больших Чисел
#
# - Дайте общее определение ЗБЧ (с минимальными требованиями к С.В.).
# - Дайте определение ЗБЧ Чебышёва.
# - Выведите ЗБЧ Бернулли из ЗБЧ Чебышёва.
# - Сформулируйте ЗБЧ Хинчина и ЗБЧ Маркова.

# %% [markdown]
# ## Основные свойства выборочных оценок
#
# - Дайте определение статистики.
# - Дайте определение статистики как точечной оценки параметра.
#
# ### Несмещенность
#
# - Дайте определение несмещенной оценки параметра.
# - Дайте определение асимптотически несмещенной оценки параметра.
#
# - Объясните, как проверить несмещенность и асимптотическую несмещенность для заданной формулы статистики.
#
# ### Состоятельность
#
# - Дайте определение состоятельной оценки параметра.
#
# - Объясните, как проверить состоятельность оценки параметра для заданной формулы статистики.
#
# - Сформулируйте теорему Манна-Вальда о сходимостях функций от случайных величин.
#
#
# ###  Асимптотическая нормальность
#
# - Сформулируйте Центральную предельную теорему (Ляпунова).
# - Найдите асимптотическое распределение среднего по i.i.d. выборке.
# - Найдите асимптотическое распределение доли по i.i.d. выборке.

# %% [markdown]
# ## Доверительные интервалы
#
# - Дайте определение точного доверительного интервала для параметра.
# - Дайте определение асимптотического доверительного интервала для параметра.
# - Объясните, что означает тот факт, что какая-то точка лежит / не лежит в доверительном интервале параметра.
# - Опишите алгоритм получения доверительного интервала при известном (асимптотическом) распределении оценки параметра.
# - Опишите алгоритм получения доверительного интервала бустрап-методом.

# %% [markdown]
# ## Углубление в статистические тесты:
#
# ### База
#
# - Объясните, что такое статистический тест и зачем они нужны.
# - Объясните утверждение "различие статистически значимо".
# - Дайте определение нулевой гипотезы, простой и сложной альтернативной гипотезы.
# - Дайте определение тестовой статистики и объясните, какому требованию она должна отвечать для построения теста по ней.
# - Дайте определение p-value статистического теста.
# - Объясните, что такое критерий отвержения нулевой гипотезы, и опишите два эквивалентных вида критериев.
# - Дайте определение $\alpha$-уровня значимости теста.
# - Дайте определение критического значения тестовой статистики.
# - Выясните, какие выводы можно сделать о верности нулевой и о верности выбранной альтернативной гипотезы, если p-value $< \alpha$.
# - Дайте определение ошибки 1 рода для некоторой нулевой гипотезы.
# - Дайте определение ошибки 2 рода для некоторой альтернативной гипотезы.
#
#
# ### Связь статистического теста и доверительного интервала
#
# - Покажите формульно, как при помощи доверительного интервала для среднего по i.i.d. выборке уровня $(1 - \alpha)$ понять результат статистического теста на равенство математического ожидания некоторому значению $\mu'$, находящегося внутри или вне этого интервала. Докажите, почему этот метод валиден.
#
# ### Мощность
#
# - Дайте определение мощности.
# - Дайте определение кривой мощности как функции от $\alpha$, $n$, MDE.
# - Объясните, как найти мощность теста при заданных параметрах $\alpha, n$, MDE.
# - Дайте определение MDE.
# - Объясните, как найти необходимое MDE и число наблюдений по уравнению мощности.
#
#
# ### Перестановочные тесты
#
# - Объясните своими словами, в чем состоит идея (в общем случае) нулевой гипотезы перестановочного теста.
# - Опишите, как по ней строится распределение тестовой статистики при верной $H_0$.
# - Выясните, какие выводы о верности нулевой и альтернативной гипотез можно сделать в случае отвержения $H_0$.
#
#
# ### Ранговые тесты
#
# - Дайте определение ранга наблюдения в выборке.
# - Объясните, чем ранговые тесты лучше, а чем хуже классических параметрических тестов, и при каких предпосылках.

# %% [markdown]
# ## Монте-Карло
#
# - Опишите идею метода Монте-Карло для оценки решения сложных аналитически задач.

# %% [markdown]
# ## Бутстрап
#
# - Опишите идею бустрап-распределения выборочной статистики. К чему и в каком смысле оно сходится? Почему?
# - Опишите недостатки бутстрап-метода тестирования и бустрап-CI.
